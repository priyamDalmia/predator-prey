# %%
import numpy as np
import matplotlib.pyplot as plt
data_i = np.load("../data_test.npy", allow_pickle=True)

# %%
mat_X = data_i[1,:,:] - data_i[0,:,:]
mat_Y = data_i[2,:,:] - data_i[3,:,:]
mat_X = np.array(mat_X, dtype=np.float32)
mat_Y = np.array(mat_Y, dtype=np.float32)
color = np.array(data_i[-1,:,:], dtype=np.float32)

# %%
plot_X, plot_Y = np.meshgrid(range(9), range(9))
plt.quiver(plot_X, -plot_Y, -mat_X, -mat_Y, color)
plt.show()

# %%
from matplotlib.ticker import AutoMinorLocator
plot_X, plot_Y = np.meshgrid(range(9), range(9))
ax = plt.quiver(plot_X, -plot_Y, -mat_X, -mat_Y, color, pivot='tip')
plt.minorticks_on()
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
from matplotlib.ticker import AutoMinorLocator
plot_X, plot_Y = np.meshgrid(range(9), range(9))
plt.quiver(plot_X, -plot_Y, -mat_X, -mat_Y, color, pivot='mid', units='width')
ax = plt.gca()
ax.set_xticks([x-0.5 for x in range(1,9)],minor=True)
ax.set_yticks([-x-0.5 for x in range(0,9)],minor=True)
plt.grid(which="minor", ls="--",lw=1, alpha=0.5)
plt.txt(2, -3, "D0")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/dalmia/Projects/predator-prey/inference/quiver.ipynb Cell 5' in <cell line: 3>()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/dalmia/Projects/predator-prey/inference/quiver.ipynb#ch0000004vscode-remote?line=0'>1</a> from matplotlib.ticker import AutoMinorLocator
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/dalmia/Projects/predator-prey/inference/quiver.ipynb#ch0000004vscode-remote?line=1'>2</a> plot_X, plot_Y = np.meshgrid(range(9), range(9))
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/dalmia/Projects/predator-prey/inference/quiver.ipynb#ch0000004vscode-remote?line=2'>3</a> plt.quiver(plot_X, -plot_Y, -mat_X, -mat_Y, color, pivot='mid', units='width', markevery=[5, 6])
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/dalmia/Projects/predator-prey/inference/quiver.ipynb#ch0000004vscode-remote?line=3'>4</a> ax = plt.gca()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/dalmia/Projects/predator-prey/inference/quiver.ipynb#ch0000004vscode-remote?line=4'>5</a> ax.set_xticks([x-0.5 for x in range(1,9)],minor=True)
#
# File ~/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/pyplot.py:2788, in quiver(data, *args, **kwargs)
#    <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/pyplot.py?line=2785'>2786</a> @_copy_docstring_and_deprecators(Axes.quiver)
#    <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/pyplot.py?line=2786'>2787</a> def quiver(*args, data=None, **kwargs):
# -> <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/pyplot.py?line=2787'>2788</a>     __ret = gca().quiver(
#    <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/pyplot.py?line=2788'>2789</a>         *args, **({"data": data} if data is not None else {}),
#    <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/pyplot.py?line=2789'>2790</a>         **kwargs)
#    <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/pyplot.py?line=2790'>2791</a>     sci(__ret)
#    <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/pyplot.py?line=2791'>2792</a>     return __ret
#
# File ~/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/__init__.py?line=1408'>1409</a> @functools.wraps(func)
#    <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/__init__.py?line=1409'>1410</a> def inner(ax, *args, data=None, **kwargs):
#    <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/__init__.py?line=1410'>1411</a>     if data is None:
# -> <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/__init__.py?line=1411'>1412</a>         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/__init__.py?line=1413'>1414</a>     bound = new_sig.bind(ax, *args, **kwargs)
#    <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/__init__.py?line=1414'>1415</a>     auto_label = (bound.arguments.get(label_namer)
#    <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/__init__.py?line=1415'>1416</a>                   or bound.kwargs.get(label_namer))
#
# File ~/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/axes/_axes.py:4988, in Axes.quiver(self, *args, **kwargs)
#    <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/axes/_axes.py?line=4985'>4986</a> # Make sure units are handled for x and y values
#    <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/axes/_axes.py?line=4986'>4987</a> args = self._quiver_units(args, kwargs)
# -> <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/axes/_axes.py?line=4987'>4988</a> q = mquiver.Quiver(self, *args, **kwargs)
#    <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/axes/_axes.py?line=4988'>4989</a> self.add_collection(q, autolim=True)
#    <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/axes/_axes.py?line=4989'>4990</a> self._request_autoscale_view()
#
# File ~/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/quiver.py:507, in Quiver.__init__(self, ax, scale, headwidth, headlength, headaxislength, minshaft, minlength, units, scale_units, angles, width, color, pivot, *args, **kw)
#     <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/quiver.py?line=504'>505</a> kw.setdefault('facecolors', color)
#     <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/quiver.py?line=505'>506</a> kw.setdefault('linewidths', (0,))
# --> <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/quiver.py?line=506'>507</a> super().__init__([], offsets=self.XY, transOffset=self.transform,
#     <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/quiver.py?line=507'>508</a>                  closed=False, **kw)
#     <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/quiver.py?line=508'>509</a> self.polykw = kw
#     <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/quiver.py?line=509'>510</a> self.set_UVC(U, V, C)
#
# File ~/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/collections.py:1187, in PolyCollection.__init__(self, verts, sizes, closed, **kwargs)
#    <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/collections.py?line=1166'>1167</a> def __init__(self, verts, sizes=None, closed=True, **kwargs):
#    <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/collections.py?line=1167'>1168</a>     """
#    <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/collections.py?line=1168'>1169</a>     Parameters
#    <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/collections.py?line=1169'>1170</a>     ----------
#    (...)
#    <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/collections.py?line=1184'>1185</a>         Forwarded to `.Collection`.
#    <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/collections.py?line=1185'>1186</a>     """
# -> <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/collections.py?line=1186'>1187</a>     super().__init__(**kwargs)
#    <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/collections.py?line=1187'>1188</a>     self.set_sizes(sizes)
#    <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/collections.py?line=1188'>1189</a>     self.set_verts(verts, closed)
#
# File ~/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/collections.py:221, in Collection.__init__(self, edgecolors, facecolors, linewidths, linestyles, capstyle, joinstyle, antialiaseds, offsets, transOffset, norm, cmap, pickradius, hatch, urls, zorder, **kwargs)
#     <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/collections.py?line=217'>218</a> self._transOffset = transOffset
#     <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/collections.py?line=219'>220</a> self._path_effects = None
# --> <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/collections.py?line=220'>221</a> self.update(kwargs)
#     <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/collections.py?line=221'>222</a> self._paths = None
#
# File ~/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/artist.py:1064, in Artist.update(self, props)
#    <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/artist.py?line=1061'>1062</a>             func = getattr(self, f"set_{k}", None)
#    <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/artist.py?line=1062'>1063</a>             if not callable(func):
# -> <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/artist.py?line=1063'>1064</a>                 raise AttributeError(f"{type(self).__name__!r} object "
#    <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/artist.py?line=1064'>1065</a>                                      f"has no property {k!r}")
#    <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/artist.py?line=1065'>1066</a>             ret.append(func(v))
#    <a href='file:///home/dalmia/Projects/predator-prey/env/lib/python3.8/site-packages/matplotlib/artist.py?line=1066'>1067</a> if ret:
#
# AttributeError: 'Quiver' object has no property 'markevery'
