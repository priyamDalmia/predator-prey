# %%
# IMPORTS
import pandas as pd 
import wandb 
import numpy as np
import matplotlib.pyplot as plt 
import os, sys
import wandb 
import time
import json
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), os.pardir)))

# %%
data = pd.read_csv('../results/follower_chaser_analysis.csv')
data[
    # (data['run_id'] == 0) & 
    (data['dimension'] == 'y') &
    (data['test'] == 'ccm_score')].round(3)
# Out:
#      run_id             mode     agent_a     agent_b       test dimension  \
# 19        0  follower_chaser  predator_0  predator_1  ccm_score         y
# 59        0  follower_chaser  predator_1  predator_0  ccm_score         y
# 99        1  follower_chaser  predator_0  predator_1  ccm_score         y
# 139       1  follower_chaser  predator_1  predator_0  ccm_score         y
# 179       2  follower_chaser  predator_0  predator_1  ccm_score         y
# 219       2  follower_chaser  predator_1  predator_0  ccm_score         y
#
#       2000   5000  10000
# 19   0.652  0.494  0.348
# 59   0.685  0.603  0.597
# 99   0.392  0.482  0.406
# 139  0.482  0.569  0.522
# 179  0.636  0.539  0.426
# 219  0.740  0.668  0.587

# %%
data = pd.read_csv('../results/chaser_chaser_analysis.csv')
data[
    # (data['run_id'] == 0) & 
    (data['dimension'] == 'x') &
    (data['test'] == 'chi-p')].round(3)
# Out:
#      run_id           mode     agent_a     agent_b   test dimension   2000  \
# 14        0  chaser_chaser  predator_0  predator_1  chi-p         x  0.630
# 54        0  chaser_chaser  predator_1  predator_0  chi-p         x  0.481
# 94        1  chaser_chaser  predator_0  predator_1  chi-p         x  0.703
# 134       1  chaser_chaser  predator_1  predator_0  chi-p         x  0.888
# 174       2  chaser_chaser  predator_0  predator_1  chi-p         x  0.900
# 214       2  chaser_chaser  predator_1  predator_0  chi-p         x  0.931
#
#       5000  10000
# 14   0.858  0.710
# 54   0.657  0.631
# 94   0.903  0.790
# 134  0.561  0.691
# 174  0.943  0.376
# 214  0.638  0.653
